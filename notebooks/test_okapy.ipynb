# %%
from pathlib import Path

import numpy as np
import pydicom as pdcm
import matplotlib.pyplot as plt

from okapy.dicomconverter.dicom_file import get_volume, get_sitk_image, get_mask, get_sitk_mask

# %%
dicom_paths =[str(f.resolve()) for f in Path("../../lymphangitis3.0/data/raw/PatientLC_1/").rglob("*") if "CT" in f.name and "RTSTRUCT" not in f.name]
rtstruct_file = [str(f.resolve()) for f in Path("../../lymphangitis3.0/data/raw/PatientLC_1/").rglob("*") if "RTSTRUCT" in f.name][0]

# %%
volume = get_volume(dicom_paths)

# %%
plt.imshow(volume.np_image[:,:,100])

# %%
mask = get_mask(rtstruct_file, dicom_paths, "GTV T")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-1010417b3ece> in <module>
# ----> 1 mask = get_mask(rtstruct_file, dicom_paths, "GTV T")
#
# ~/python_wkspce/okapy/okapy/dicomconverter/dicom_file.py in get_mask(rtstruct_file, ref_dicom_paths, label)
#      32                                        stop_before_pixels=True).Modality
#      33     ref_dicom = DicomFileBase.get(modality)(dicom_paths=ref_dicom_paths)
# ---> 34     dicom = RtstructFile(dicom_paths=[rtstruct_file],
#      35                          reference_frame=ref_dicom.reference_frame)
#      36     return dicom.get_volume(label)
#
# ~/python_wkspce/okapy/okapy/dicomconverter/dicom_file.py in __init__(self, reference_image, reference_frame, *args, **kwargs)
#     347         super().__init__(*args, **kwargs)
#     348         self.contours = None
# ...

# %%
positions = [pdcm.filereader.dcmread(f, stop_before_pixels=True).ImagePositionPatient for f in dicom_paths]

# %%
sitk_image = get_sitk_image(dicom_paths)

# %%
sitk_image.GetDirection()

# %%
np.repeat([1,2,3], 3)
